# %% [markdown]
# # Import libraries and data

# %%
#import libraries
import pandas as pd
import numpy as np
import random
random.seed(1)

#set plot style
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %% [markdown]
# ## Generate codebook

# %%
# Import dataframe with multi index column names for generating the codebook
df1 = pd.read_csv('data_g1.csv', header=[0, 1])

# Prepare the codebook
codebook = df1.columns.to_frame(index=0, name=['question', 'options'])

# %%
df1.head()
# Out:
#        Respondent ID       Collector ID              Start Date  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1      Unnamed: 2_level_1
# 0        10858623557          241097711  07/14/2019 06:03:59 PM
# 1        10858623386          241097711  07/14/2019 06:03:44 PM
# 2        10858622504          241097659  07/14/2019 06:02:36 PM
# 3        10858622198          241097659  07/14/2019 06:02:20 PM
# 4        10858621248          241097608  07/14/2019 06:01:14 PM
#
#                  End Date         IP Address      Email Address  \
#        Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
# 0  07/14/2019 06:04:08 PM                                   NaN
# 1  07/14/2019 06:03:55 PM                NaN                NaN
# 2  07/14/2019 06:02:54 PM                                   NaN
# 3  07/14/2019 06:02:33 PM                                   NaN
# 4  07/14/2019 06:01:33 PM                                   NaN
#
#           First Name          Last Name      Custom Data 1  \
#   Unnamed: 6_level_1 Unnamed: 7_level_1 Unnamed: 8_level_1
# 0                NaN                NaN                NaN
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3                NaN                NaN                NaN
# 4                NaN                NaN                NaN
#
#   Which of the following devices do you use to connect to the internet? (Check all that apply)   \
#                                                                                Desktop computer
# 0                                                NaN
# 1                                   Desktop computer
# 2                                                NaN
# 3                                   Desktop computer
# 4                                   Desktop computer
#
#   Unnamed: 10_level_0 Unnamed: 11_level_0 Unnamed: 12_level_0  \
#       Laptop computer              Tablet         Smart phone
# 0                 NaN              Tablet         Smart phone
# 1                 NaN                 NaN                 NaN
# 2     Laptop computer                 NaN         Smart phone
# 3                 NaN                 NaN         Smart phone
# 4                 NaN              Tablet                 NaN
#
#      Unnamed: 13_level_0  \
#   Other (please specify)
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                 dfsdsf
#
#   Overall, how satisfied or dissatisfied are you with our company?  \
#                                                           Response
# 0                                 Somewhat satisfied
# 1                                  Very dissatisfied
# 2                                 Somewhat satisfied
# 3                                 Somewhat satisfied
# 4                 Neither satisfied nor dissatisfied
#
#   To what extent do you agree with each of the following?  \
#                                The website is easy to use
# 0                                     Strongly agree
# 1                                  Strongly disagree
# 2                                     Strongly agree
# 3                                              Agree
# 4                                          Undecided
#
#                          Unnamed: 16_level_0  \
#   The information on the website is credible
# 0                             Strongly agree
# 1                          Strongly disagree
# 2                             Strongly agree
# 3                                   Disagree
# 4                                      Agree
#
#                             Unnamed: 17_level_0  \
#   I will likely return to the website in future
# 0                                Strongly agree
# 1                             Strongly disagree
# 2                                     Undecided
# 3                                         Agree
# 4                                     Undecided
#
#                   Unnamed: 18_level_0
#   I find the website to be attractive
# 0                      Strongly agree
# 1                   Strongly disagree
# 2                      Strongly agree
# 3                            Disagree
# 4                           Undecided

# %% [markdown]
# ## Merge the dataset that you download directly from Survey Monkey

# %%
# Prepare the merged version of dataframe, please replace the file names below
df_1 = pd.read_csv("data_g1.csv", header=None, prefix="Q").iloc[2:]
df_2 = pd.read_csv("data_g1.csv", header=None, prefix="Q").iloc[2:]


# Pass in group name
df_1["group"] = "group_1"
df_2["group"] = "group_2"

# Merge different datasets into one dataframe
df = df_1.append(df_2, ignore_index=True)

# %%
df.head()
# Out:
#             Q0         Q1                      Q2                      Q3  \
# 0  10858623557  241097711  07/14/2019 06:03:59 PM  07/14/2019 06:04:08 PM
# 1  10858623386  241097711  07/14/2019 06:03:44 PM  07/14/2019 06:03:55 PM
# 2  10858622504  241097659  07/14/2019 06:02:36 PM  07/14/2019 06:02:54 PM
# 3  10858622198  241097659  07/14/2019 06:02:20 PM  07/14/2019 06:02:33 PM
# 4  10858621248  241097608  07/14/2019 06:01:14 PM  07/14/2019 06:01:33 PM
#
#     Q4   Q5   Q6   Q7   Q8                Q9              Q10     Q11  \
# 0       NaN  NaN  NaN  NaN               NaN              NaN  Tablet
# 1  NaN  NaN  NaN  NaN  NaN  Desktop computer              NaN     NaN
# 2       NaN  NaN  NaN  NaN               NaN  Laptop computer     NaN
# 3       NaN  NaN  NaN  NaN  Desktop computer              NaN     NaN
# 4       NaN  NaN  NaN  NaN  Desktop computer              NaN  Tablet
#
#            Q12     Q13                                 Q14                Q15  \
# 0  Smart phone     NaN                  Somewhat satisfied     Strongly agree
# 1          NaN     NaN                   Very dissatisfied  Strongly disagree
# 2  Smart phone     NaN                  Somewhat satisfied     Strongly agree
# 3  Smart phone     NaN                  Somewhat satisfied              Agree
# 4          NaN  dfsdsf  Neither satisfied nor dissatisfied          Undecided
#
#                  Q16                Q17                Q18    group
# 0     Strongly agree     Strongly agree     Strongly agree  group_1
# 1  Strongly disagree  Strongly disagree  Strongly disagree  group_1
# 2     Strongly agree          Undecided     Strongly agree  group_1
# 3           Disagree              Agree           Disagree  group_1
# 4              Agree          Undecided          Undecided  group_1

# %% [markdown]
# ## Faker package is used here to generate a larger fake dataset (instead of using the manually generated fake data from Survey Monkey)

# %%
from faker import Faker

fake = Faker()

# import a Provider
from faker.providers import BaseProvider

from datetime import datetime, timedelta

# create my new provider class
class MyProvider(BaseProvider):
    # define a method that return a random expense type
    def devDesktop(self):
        foo = ["Desktop computer", np.nan]
        return random.choice(foo)

    def devLaptop(self):
        foo = ["Laptop computer", np.nan]
        return random.choice(foo)

    def devTablet(self):
        foo = ["Tablet", np.nan]
        return random.choice(foo)

    def devPhone(self):
        foo = ["Smart phone", np.nan]
        return random.choice(foo)

    def satLevel(self):
        foo = [
            "Very satisfied",
            "Somewhat satisfied",
            "Neither satisfied nor dissatisfied",
            "Somewhat dissatisfied",
            "Very dissatisfied",
        ]
        return random.choice(foo)

    def agreeLevel(self):
        foo = ["Strongly agree", "Agree", "Undecided", "Disagree", "Strongly disagree"]
        return random.choice(foo)

    def group(self):
        foo = ["Group 1", "Group 2"]
        return random.choice(foo)


# then add my new provider to faker instance
fake.add_provider(MyProvider)

# %%
def createFakeDataset(num_examples):
    """Function that creates a fake dataset using the python module Faker

    Args:
        num_examples (int): number of fake examples to generate

    Returns:
        pandas.core.frame.DataFrame: the final dataframe

    """

    l_response_ID = []
    l_collector_ID = []
    l_start_dates = []
    l_end_dates = []
    l_devDesktop = []
    l_devLaptop = []
    l_devTablet = []
    l_devPhone = []
    l_devOther = []
    l_satLevel = []
    l_matrix1 = []
    l_matrix2 = []
    l_matrix3 = []
    l_matrix4 = []
    l_group = []
    l_missing = []

    for _ in range(num_examples):
        l_response_ID.append(fake.random_int(min=10000000000, max=99999999999))
        l_collector_ID.append(fake.random_int(min=100000000, max=999999999))
        # create a fake date within 30 days
        fake_date = fake.date_time_between(
            start_date="-30d", end_date="now", tzinfo=None
        )
        l_start_dates.append(fake_date)
        l_end_dates.append(fake_date + timedelta(minutes=random.randrange(90)))
        # create fake data for device question
        l_devDesktop.append(fake.devDesktop())
        l_devLaptop.append(fake.devLaptop())
        l_devTablet.append(fake.devTablet())
        l_devPhone.append(fake.devPhone())
        # create fake data for satisfaction question
        l_satLevel.append(fake.satLevel())
        # create fake data for the matrix question
        l_matrix1.append(fake.agreeLevel())
        l_matrix2.append(fake.agreeLevel())
        l_matrix3.append(fake.agreeLevel())
        l_matrix4.append(fake.agreeLevel())
        # create fake data for group
        l_group.append(fake.group())
        # create a list of missing values
        l_missing.append(np.nan)

    # create a dataframe
    df = pd.DataFrame(
        {
            "Q0": l_response_ID,
            "Q1": l_collector_ID,
            "Q2": l_start_dates,
            "Q3": l_end_dates,
            "Q4": l_missing,
            "Q5": l_missing,
            "Q6": l_missing,
            "Q7": l_missing,
            "Q8": l_missing,
            "Q9": l_devDesktop,
            "Q10": l_devLaptop,
            "Q11": l_devTablet,
            "Q12": l_devPhone,
            "Q13": l_missing,
            "Q14": l_satLevel,
            "Q15": l_matrix1,
            "Q16": l_matrix2,
            "Q17": l_matrix3,
            "Q18": l_matrix4,
            "group": l_group,
        }
    )

    return df

# %%
df = createFakeDataset(200)

# %%
df.head()
# Out:
#             Q0         Q1                  Q2                  Q3  Q4  Q5  Q6  \
# 0  85606632841  360966973 2019-08-11 11:58:45 2019-08-11 12:15:45 NaN NaN NaN
# 1  64790282385  951530579 2019-09-01 21:30:02 2019-09-01 21:33:02 NaN NaN NaN
# 2  39222344104  499801836 2019-09-02 17:35:06 2019-09-02 17:37:06 NaN NaN NaN
# 3  20658279515  156042285 2019-08-20 17:09:27 2019-08-20 18:19:27 NaN NaN NaN
# 4  84803988427  729471919 2019-08-29 18:17:09 2019-08-29 18:40:09 NaN NaN NaN
#
#    Q7  Q8                Q9              Q10     Q11          Q12  Q13  \
# 0 NaN NaN  Desktop computer              NaN  Tablet          NaN  NaN
# 1 NaN NaN               NaN              NaN  Tablet          NaN  NaN
# 2 NaN NaN  Desktop computer  Laptop computer     NaN  Smart phone  NaN
# 3 NaN NaN  Desktop computer              NaN  Tablet  Smart phone  NaN
# 4 NaN NaN               NaN  Laptop computer     NaN          NaN  NaN
#
#                                   Q14             Q15                Q16  \
# 0               Somewhat dissatisfied        Disagree           Disagree
# 1  Neither satisfied nor dissatisfied           Agree  Strongly disagree
# 2               Somewhat dissatisfied  Strongly agree  Strongly disagree
# 3               Somewhat dissatisfied       Undecided     Strongly agree
# 4                   Very dissatisfied           Agree          Undecided
#
#               Q17                Q18    group
# 0           Agree     Strongly agree  Group 2
# 1  Strongly agree          Undecided  Group 1
# 2           Agree           Disagree  Group 2
# 3        Disagree  Strongly disagree  Group 1
# 4       Undecided  Strongly disagree  Group 2

# %%
df.group.value_counts()
# Out:
# Group 1    102
# Group 2     98
# Name: group, dtype: int64

# %% [markdown]
# # Visualize multi-answer question by group (Checkboxes)

# %%
# Prepare the summary table (please clean the data beforehand)
def prepare_table(data, column_range, group_column_name='group'):
    res = []
    col_range_index = list(column_range)
    group_index = df.columns.to_list().index(group_column_name)
    col_range_index.append(group_index)
    series = data.iloc[:, col_range_index].groupby([group_column_name]).count().unstack()
    for group in series.index.levels[1]:
        for var in series.index.levels[0]:
            res.append(
                [
                    (series[var][group] / data.loc[:,group_column_name].value_counts()[group] * 100).round(2),
                    codebook.iloc[int(var[1:]), 1],
                    group,
                ]
            )
    return pd.DataFrame(columns=["percentage(%)", "options", group_column_name], data=res)


# Generate the checkbox chart based on the summary table
def gen_chart_checkbox(data, column_range, group_column_name='group'):
    listOfGroup = list(data.loc[:,group_column_name].unique())
    listOfGroup.sort()
    table_sum = prepare_table(df, column_range, group_column_name)

    print("Number of answers in each group: ")
    print(data.loc[:,group_column_name].value_counts())

    fig, ax = plt.subplots(figsize=(10, 8))
    ax = sns.barplot(
        x="percentage(%)",
        y="options",
        hue=group_column_name,
        hue_order=listOfGroup,
        data=table_sum,
    )
    ax.set(xlim=(0, 100))
    ax.set_ylabel("")
    plt.title(codebook.iloc[column_range[0], 0], fontsize=15)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0, title="group")
    return plt.show()

# %%
gen_chart_checkbox(df, range(9,13))
# Out:
# Number of answers in each group:
# Group 1    102
# Group 2     98
# Name: group, dtype: int64

# %% [markdown]
# # Visualize single-answer question by group (Radio Button)

# %%
# Generate a chart to visualize single-answer questions
def gen_chart_radiobutton(data, question_name, index, group_column_name='group'):
    print("Number of answers in each group: ")
    print(data[[question_name, group_column_name]].groupby(group_column_name).count())
    i_counts = (
        data.groupby([group_column_name])[question_name]
        .value_counts(normalize=True)
        .rename("percentage(%)")
        .mul(100)
        .reset_index()
        .round(2)
    )

    listOfGroup = list(df.loc[:,group_column_name].unique())
    listOfGroup.sort()

    fig, ax = plt.subplots(figsize=(10, 8))

    fig = sns.barplot(
        x="percentage(%)",
        y=question_name,
        order=index,
        hue=group_column_name,
        hue_order=listOfGroup,
        data=i_counts,
    )

    plt.title(codebook.iloc[int(question_name[1:]), 0])
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0, title="group")
    ax.set(xlim=(0, 100))
    ax.set_ylabel("")
    return plt.show()

# %%
index = [
    "Very satisfied",
    "Somewhat satisfied",
    "Neither satisfied nor dissatisfied",
    "Somewhat dissatisfied",
    "Very dissatisfied",
]
gen_chart_radiobutton(df, "Q14", index)
# Out:
# Number of answers in each group:
#          Q14
# group
# Group 1  102
# Group 2   98

# %% [markdown]
# # Visualize matrix question by group

# %%
# Generate summary data for each group
def gen_table(data, group_name, col_range, group_column_name='group'):
    data_sub = data[data[group_column_name] == group_name].iloc[:, col_range].dropna(how="all")
    for var in data_sub.columns:
        data_sub[var] = data_sub[var].map(
            {
                "Strongly agree": 5,
                "Agree": 4,
                "Undecided": 3,
                "Disagree": 2,
                "Strongly disagree": 1,
            }
        )
    table = data_sub.describe().loc[["mean", "std", "count"]].T

    index = []

    for var in table.index:
        i = int(var[1:])
        index.append(codebook.iloc[i, 1])

    table["item"] = index

    # table["item_n"] = range(len(index),0,-1)
    table["item_n"] = range(0, len(index))
    return table

# %%
gen_table(df,'Group 1', range(15,19))
# Out:
#          mean       std  count                                           item  \
# Q15  3.205882  1.269117  102.0                     The website is easy to use
# Q16  2.862745  1.509306  102.0     The information on the website is credible
# Q17  3.039216  1.482048  102.0  I will likely return to the website in future
# Q18  2.960784  1.441407  102.0            I find the website to be attractive
#
#      item_n
# Q15       0
# Q16       1
# Q17       2
# Q18       3

# %%
# Generate a chart to compare the importance of missing features across two groups
def compare_importance(data, groups, col_range, group_column_name='group'):

    group_name_to_describe_data = {}

    #Create a dictionary to save the summary data for each group
    for i, group_name in enumerate(groups):
        group_name_to_describe_data[group_name] = "data_describe_%s" % i

    for group_name in groups:
        table = gen_table(data, group_name, col_range, group_column_name)
        group_name_to_describe_data[group_name] = table

    #Get the item list and index
    items = table.item.tolist()
    item_n = table.item_n.tolist()
    
    # Visualize the mean value with the 95% confidence interval
    # Change the figsize if you have more yticks
    plt.figure(num=None, figsize=(12, 6), dpi=90, facecolor="w", edgecolor="k")
    ax = plt.axes()

    for i, group_name in enumerate(groups):
        plt.errorbar(
            group_name_to_describe_data[group_name]["mean"].astype(float),
            group_name_to_describe_data[group_name]["item_n"] - 0.1 * i,
            xerr=1.96
            * (
                group_name_to_describe_data[group_name]["std"].astype(float)
                / (group_name_to_describe_data[group_name]["count"] ** 0.5)
            ),
            fmt="o",
            elinewidth=0.5,
            capsize=4,
            marker="o",
            ms=4,
            label=group_name,
        )

    ax.set_xlim(1, 5)
    
    ax.set_yticks(item_n)
    ax.set_yticklabels(labels=items, fontdict={'fontsize':16})

    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0, title="group")
    plt.title("Compare the mean values across groups (scale 1-5)", fontsize=16)

    return plt.show()

# %%
# Compare the Group 1 and 2
compare_importance(df, ['Group 1', 'Group 2'], range(15,19))
